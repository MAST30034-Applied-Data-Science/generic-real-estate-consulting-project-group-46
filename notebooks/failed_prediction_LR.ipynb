# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
df = pd.read_csv("./2016_data.csv")

# %%
df_21 = pd.read_csv("./2021_data.csv")

# %%
bed_16 = pd.read_csv("./df_bed_2016(1).csv")
bed_21 = pd.read_csv("./df_bed_2021(1).csv")

bed_16 = bed_16.rename(columns={'SA2_2016': 'SA2_CODE16'})
bed_21 = bed_21.rename(columns={'SA2_2021': 'SA2_CODE16'})

# %%
bed_21
# Out:
#      SA2_CODE16  avg_beds_2021
# 0     201011001        3.58401
# 1     201011002        3.01184
# 2     201011005        3.45792
# 3     201011006        3.47034
# 4     201011007        3.62337
# ..          ...            ...
# 519   217041478        3.25182
# 520   217041479        3.15654
# 521   217041480        2.94790
# 522   297979799            NaN
# 523   299999499            NaN
#
# [524 rows x 2 columns]

# %%
df
# Out:
#      SA2_CODE16   avg_income  Median_tot_fam_inc_weekly  Tot_P_P  \
# 0     201011001  1862.008106                       1833    11654
# 1     201011002  1794.138669                       1867    12046
# 2     201011003  1540.676654                       1574    23083
# 3     201011004  1236.168969                       1242    24231
# 4     201011005  1937.960572                       1921     7153
# ..          ...          ...                        ...      ...
# 459   217041478  1536.300891                       1470     9432
# 460   217041479  1520.163543                       1510    21097
# 461   217041480  1485.872396                       1498    12921
# 462   297979799          NaN                          0       29
# 463   299999499          NaN                          0     7565
#
#      Median_age_persons  Median_rent_weekly
# 0                    34                 310
# 1                    42                 260
# 2                    39                 250
# 3                    36                 240
# 4                    38                 300
# ..                  ...                 ...
# 459                  44                 223
# 460                  39                 250
# 461                  43                 250
# 462                  49                   0
# 463                  34                   0
#
# [464 rows x 6 columns]

# %%
df_21 = df_21.rename(columns={'SA2_CODE21': 'SA2_CODE16','Median_rent_weekly':'Median_rent_weekly_21'})

# %%
# df_new = pd.merge(df, df_21[['SA2_CODE16','Median_rent_weekly_21']], how = 'left', on='SA2_CODE16')
df = pd.merge(df, bed_16,  on='SA2_CODE16')
df_new = pd.merge(df, df_21[['SA2_CODE16','Median_rent_weekly_21']],  on='SA2_CODE16')

# %%
df_new.Median_rent_weekly_21.isnull().sum()
# Out:
# 0

# %%
df_new['label'] = (df_new['Median_rent_weekly_21']-df_new['Median_rent_weekly'])/(df_new['Median_rent_weekly']+1e-5)

# %%
df_new
# Out:
#      SA2_CODE16   avg_income  Median_tot_fam_inc_weekly  Tot_P_P  \
# 0     201011001  1862.008106                       1833    11654
# 1     201011002  1794.138669                       1867    12046
# 2     201011005  1937.960572                       1921     7153
# 3     201011006  1502.571300                       1465     7082
# 4     201011007  1815.179581                       1745     3932
# ..          ...          ...                        ...      ...
# 405   217041478  1536.300891                       1470     9432
# 406   217041479  1520.163543                       1510    21097
# 407   217041480  1485.872396                       1498    12921
# 408   297979799          NaN                          0       29
# 409   299999499          NaN                          0     7565
#
#      Median_age_persons  Median_rent_weekly  avg_beds_2016  \
# 0                    34                 310        3.48760
# 1                    42                 260        2.97632
# 2                    38                 300        3.41499
# 3                    36                 260        3.32975
# 4                    41                 236        3.47918
# ..                  ...                 ...            ...
# 405                  44                 223        3.20240
# 406                  39                 250        3.11719
# 407                  43                 250        2.91604
# 408                  49                   0            NaN
# 409                  34                   0            NaN
#
#      Median_rent_weekly_21     label
# 0                      370  0.193548
# 1                      313  0.203846
# 2                      330  0.100000
# 3                      360  0.384615
# 4                      350  0.483051
# ..                     ...       ...
# 405                    280  0.255605
# 406                    300  0.200000
# 407                    287  0.148000
# 408                      0  0.000000
# 409                      0  0.000000
#
# [410 rows x 9 columns]

# %%
df_train = df_new[(df_new.Median_rent_weekly != 0) & (df_new.avg_income.notna())]
df_train = df_train[df_train.Tot_P_P > 1000]

# %%
df_train
# Out:
#      SA2_CODE16   avg_income  Median_tot_fam_inc_weekly  Tot_P_P  \
# 0     201011001  1862.008106                       1833    11654
# 1     201011002  1794.138669                       1867    12046
# 2     201011005  1937.960572                       1921     7153
# 3     201011006  1502.571300                       1465     7082
# 4     201011007  1815.179581                       1745     3932
# ..          ...          ...                        ...      ...
# 403   217031476  1228.678722                       1205     3429
# 404   217041477  1539.953835                       1482     6648
# 405   217041478  1536.300891                       1470     9432
# 406   217041479  1520.163543                       1510    21097
# 407   217041480  1485.872396                       1498    12921
#
#      Median_age_persons  Median_rent_weekly  avg_beds_2016  \
# 0                    34                 310        3.48760
# 1                    42                 260        2.97632
# 2                    38                 300        3.41499
# 3                    36                 260        3.32975
# 4                    41                 236        3.47918
# ..                  ...                 ...            ...
# 403                  52                 245        2.90776
# 404                  42                 150        3.29440
# 405                  44                 223        3.20240
# 406                  39                 250        3.11719
# 407                  43                 250        2.91604
#
#      Median_rent_weekly_21     label
# 0                      370  0.193548
# 1                      313  0.203846
# 2                      330  0.100000
# 3                      360  0.384615
# 4                      350  0.483051
# ..                     ...       ...
# 403                    285  0.163265
# 404                    200  0.333333
# 405                    280  0.255605
# 406                    300  0.200000
# 407                    287  0.148000
#
# [396 rows x 9 columns]

# %%
# df_train['Median_tot_fam_inc_weekly_avg_income_div'] = (df_train['Median_tot_fam_inc_weekly'] - df_train['avg_income']) / df_train['avg_income']
df_train['Median_age_persons_Tot_P_P_div'] = (df_train['Median_age_persons'] - df_train['Tot_P_P']) / df_train['Tot_P_P']

# %%
df_train.isnull().any()
# Out:
# SA2_CODE16                        False
# avg_income                        False
# Median_tot_fam_inc_weekly         False
# Tot_P_P                           False
# Median_age_persons                False
# Median_rent_weekly                False
# avg_beds_2016                     False
# Median_rent_weekly_21             False
# label                             False
# Median_age_persons_Tot_P_P_div    False
# dtype: bool

# %%
df_train.corr()
# Out:
#                                 SA2_CODE16  avg_income  \
# SA2_CODE16                        1.000000   -0.062573
# avg_income                       -0.062573    1.000000
# Median_tot_fam_inc_weekly        -0.115391    0.964909
# Tot_P_P                           0.101324    0.222674
# Median_age_persons               -0.107661   -0.358891
# Median_rent_weekly               -0.060528    0.818510
# avg_beds_2016                     0.168866    0.089118
# Median_rent_weekly_21            -0.074997    0.824265
# label                             0.013276   -0.411898
# Median_age_persons_Tot_P_P_div   -0.042827   -0.324905
#
#                                 Median_tot_fam_inc_weekly   Tot_P_P  \
# SA2_CODE16                                      -0.115391  0.101324
# avg_income                                       0.964909  0.222674
# Median_tot_fam_inc_weekly                        1.000000  0.206118
# Tot_P_P                                          0.206118  1.000000
# Median_age_persons                              -0.298304 -0.351370
# Median_rent_weekly                               0.764315  0.437130
# avg_beds_2016                                   -0.088231 -0.064764
# Median_rent_weekly_21                            0.767976  0.407135
# label                                           -0.384358 -0.412805
# Median_age_persons_Tot_P_P_div                  -0.291505 -0.821190
#
#                                 Median_age_persons  Median_rent_weekly  \
# SA2_CODE16                               -0.107661           -0.060528
# avg_income                               -0.358891            0.818510
# Median_tot_fam_inc_weekly                -0.298304            0.764315
# Tot_P_P                                  -0.351370            0.437130
# Median_age_persons                        1.000000           -0.503832
# Median_rent_weekly                       -0.503832            1.000000
# avg_beds_2016                             0.125987           -0.015085
# Median_rent_weekly_21                    -0.421669            0.973131
# label                                     0.537307           -0.680127
# Median_age_persons_Tot_P_P_div            0.573890           -0.559171
#
#                                 avg_beds_2016  Median_rent_weekly_21  \
# SA2_CODE16                           0.168866              -0.074997
# avg_income                           0.089118               0.824265
# Median_tot_fam_inc_weekly           -0.088231               0.767976
# Tot_P_P                             -0.064764               0.407135
# Median_age_persons                   0.125987              -0.421669
# Median_rent_weekly                  -0.015085               0.973131
# avg_beds_2016                        1.000000               0.060201
# Median_rent_weekly_21                0.060201               1.000000
# label                                0.162267              -0.520447
# Median_age_persons_Tot_P_P_div       0.084273              -0.511762
#
#                                    label  Median_age_persons_Tot_P_P_div
# SA2_CODE16                      0.013276                       -0.042827
# avg_income                     -0.411898                       -0.324905
# Median_tot_fam_inc_weekly      -0.384358                       -0.291505
# Tot_P_P                        -0.412805                       -0.821190
# Median_age_persons              0.537307                        0.573890
# Median_rent_weekly             -0.680127                       -0.559171
# avg_beds_2016                   0.162267                        0.084273
# Median_rent_weekly_21          -0.520447                       -0.511762
# label                           1.000000                        0.566007
# Median_age_persons_Tot_P_P_div  0.566007                        1.000000

# %%
df_train.columns
# Out:
# Index(['SA2_CODE16', 'avg_income', 'Median_tot_fam_inc_weekly', 'Tot_P_P',
#        'Median_age_persons', 'Median_rent_weekly', 'avg_beds_2016',
#        'Median_rent_weekly_21', 'label', 'Median_age_persons_Tot_P_P_div'],
#       dtype='object')

# %%
#Test Set
df_ceshi = df_21[['SA2_CODE16', 'avg_income', 'Tot_P_P','Median_age_persons']]
df_ceshi = pd.merge(df_ceshi, bed_21,  on='SA2_CODE16')

# %%
# df_ceshi['Median_age_persons_Tot_P_P_div'] = (df_ceshi['Median_age_persons'] - df_ceshi['Tot_P_P']) / df_ceshi['Tot_P_P']

# %%
df_ceshi = df_ceshi[(df_ceshi.avg_income.notna())]
df_ceshi = df_ceshi[df_ceshi.Tot_P_P > 1000]

# %%
df_ceshi.isnull().any()
# Out:
# SA2_CODE16            False
# avg_income            False
# Tot_P_P               False
# Median_age_persons    False
# avg_beds_2021         False
# dtype: bool

# %%
df_ceshi
# Out:
#      SA2_CODE16   avg_income  Tot_P_P  Median_age_persons  avg_beds_2021
# 0     201011001  2269.734428    16835                  34        3.58401
# 1     201011002  2130.397616    12131                  45        3.01184
# 2     201011005  2313.068493     7261                  42        3.45792
# 3     201011006  1857.987190    10661                  33        3.47034
# 4     201011007  2311.064133     4230                  41        3.62337
# ..          ...          ...      ...                 ...            ...
# 517   217031476  1628.483882     4008                  52        2.98404
# 518   217041477  1937.815824     7018                  42        3.31098
# 519   217041478  1905.366053    10014                  46        3.25182
# 520   217041479  1850.573197    22405                  40        3.15654
# 521   217041480  1823.943042    13337                  44        2.94790
#
# [509 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
std_scaler = MinMaxScaler()
df_train_scaled = std_scaler.fit_transform(df_train[[f for f in df_train.columns if f not in 
                                            ['Median_rent_weekly','Median_rent_weekly_21',
                                             'Median_age_persons_Tot_P_P_div',
                                            'Median_tot_fam_inc_weekly', 'label']]])

# %%
df_ceshi_scaled = std_scaler.fit_transform(df_ceshi[[f for f in df_ceshi.columns if f not in 
                                            ['Median_rent_weekly','Median_rent_weekly_21',
                                             'Median_age_persons_Tot_P_P_div',
                                            'Median_tot_fam_inc_weekly', 'label']]])

# %%
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(df_train[['label']])

# %%
df_train_scaled = pd.DataFrame(df_train_scaled)

# %%
df_train_scaled
# Out:
#                 0         1         2         3         4
# 0    0.000000e+00  0.442336  0.427161  0.285714  0.769793
# 1    6.238117e-08  0.406492  0.445594  0.514286  0.548764
# 2    2.495247e-07  0.482448  0.215508  0.400000  0.738403
# 3    3.119058e-07  0.252509  0.212170  0.342857  0.701554
# 4    3.742870e-07  0.417604  0.064046  0.485714  0.766153
# ..            ...       ...       ...       ...       ...
# 391  9.993759e-01  0.107861  0.040393  0.800000  0.519125
# 392  9.999998e-01  0.272252  0.191761  0.514286  0.686272
# 393  9.999999e-01  0.270323  0.322675  0.571429  0.646500
# 394  9.999999e-01  0.261800  0.871203  0.428571  0.609663
# 395  1.000000e+00  0.243690  0.486739  0.542857  0.522705
#
# [396 rows x 5 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_train_scaled, y_train_scaled, 
                                                    test_size = 0.2, random_state = 23)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (316, 5)
# (316, 1)
# (80, 5)
# (80, 1)

# %%
from sklearn import linear_model

# %%
lr = linear_model.LinearRegression()
lr.fit(X_train,y_train)

y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

print('The MSE is:', mean_squared_error(y_test, y_pred))

print('The R2 is:', r2_score(y_test, y_pred))

print('The MAE is:', mean_absolute_error(y_test, y_pred))
# Out:
# The MSE is: 0.006255038523831538
# The R2 is: 0.46615876342906526
# The MAE is: 0.04833936527887263

# %%
from sklearn.neural_network import MLPRegressor

# %%
clf = MLPRegressor(solver='lbfgs', alpha=1e-3, hidden_layer_sizes=(80,7), activation='relu', random_state=20)

clf.fit(X_train,y_train)

y_pred_2 = clf.predict(X_test)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1599: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
print('The R2 is:', r2_score(y_train, clf.predict(X_train)))
# Out:
# The R2 is: 0.6578309964607314

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

print('The MSE is:', mean_squared_error(y_test, y_pred_2))

print('The R2 is:', r2_score(y_test, y_pred_2))

print('The MAE is:', mean_absolute_error(y_test, y_pred_2))
# Out:
# The MSE is: 0.006339482826955961
# The R2 is: 0.4589517972322049
# The MAE is: 0.04530666148050463

# %%
clf.predict(X_test)
# Out:
# array([0.30959294, 0.32521209, 0.28685705, 0.2689224 , 0.3247142 ,
#        0.32318272, 0.29351947, 0.26056933, 0.32540189, 0.54132993,
#        0.18359377, 0.36161498, 0.27038194, 0.31657693, 0.31481116,
#        0.38457512, 0.24611809, 0.25233141, 0.28313546, 0.28722532,
#        0.32540664, 0.39503391, 0.35341767, 0.36793937, 0.34078948,
#        0.40621666, 0.25752959, 0.30117871, 0.70533413, 0.44980052,
#        0.2600838 , 0.32122664, 0.24634147, 0.26631056, 0.21100292,
#        0.31525359, 0.29150919, 0.26215347, 0.40901641, 0.16042308,
#        0.45876555, 0.2033943 , 0.31202952, 0.13872118, 0.30337426,
#        0.4695462 , 0.31290455, 0.20687615, 0.29805546, 0.27572477,
#        0.31084008, 0.43000811, 0.29099026, 0.3199542 , 0.40155813,
#        0.39144793, 0.29514434, 0.30303407, 0.45028366, 0.2759555 ,
#        0.35487859, 0.44073118, 0.48455605, 0.34964844, 0.26290797,
#        0.23613849, 0.33104919, 0.25912046, 0.27176633, 0.22290437,
#        0.34789084, 0.38588617, 0.37817568, 0.44188582, 0.29843252,
#        0.28884809, 0.41650157, 0.35507483, 0.27313272, 0.1879458 ])

# %%
cengindex = 0
for wi in clf.coefs_:
    cengindex += 1  # 第几层神经网络
    print('第%d层网络层:' % cengindex)
    print('权重矩阵维度:',wi.shape)
    print('系数矩阵：\n',wi)
# Out:
# 第1层网络层:
# 权重矩阵维度: (5, 80)
# 系数矩阵：
#  [[ 4.44558582e-02  3.32196797e-01  1.44313525e-01  3.81270398e-01
#   -5.27354231e-01  1.55879353e-01 -4.95374949e-02 -2.17635248e-02
#    7.96755263e-02 -1.54431267e-01 -1.62962064e-01  2.30173269e-01
#    6.72413128e-02  5.37240431e-01  1.20156390e-01 -2.33720625e-01
#    6.94896554e-03  1.16955010e-01 -1.22777844e-01 -1.23683309e-01
#    1.70277776e-01  2.34597380e-01  8.07252350e-03 -4.44600922e-01
#    2.57153507e-01  5.78663801e-02  8.01485936e-02  3.75266468e-01
#   -5.00799168e-02  1.09372662e-02  1.27920231e-01  7.23167742e-02
#   -2.75787764e-02 -4.69304857e-01  1.87090722e-01  1.37198355e-01
#   -9.37584476e-02  5.09212665e-02 -1.19232812e-01  1.23732015e-01
#    6.39887346e-02  2.89794329e-02 -9.15139914e-02 -5.21872799e-02
#   -1.21139373e-01  2.64703206e-02 -4.49215261e-03 -1.60541777e-01
#    1.60168780e-01 -1.73326474e-01  3.08758669e-01 -4.60830332e-02
#    1.41209941e-01  1.09240174e-01 -3.37176171e-02  2.88157324e-01
#    1.88158161e-01  6.99963381e-02 -4.71745033e-02  1.83043961e-02
#   -8.43290742e-03 -2.84490551e-01  6.14168844e-02  6.38317881e-02
#   -2.31247362e-01 -5.69322034e-02 -1.93223330e-01]
#  [-7.12790655e-02 -2.56231753e-01  1.02150193e-01  1.55249446e-01
#   -1.18401525e-01 -5.12139891e-02  2.00333090e-01]
#  [-3.21290347e-02  1.82664283e-01  1.44469115e-01 -1.93527502e-01
#   -1.74490180e-01 -1.54400843e-01 -2.11310917e-01]]
# 第3层网络层:
# 权重矩阵维度: (7, 1)
# 系数矩阵：
#  [[-0.77326283]
#  [-0.46826283]
#  [ 0.51280978]
#  [ 0.01657018]
#  [ 0.2356874 ]
#  [ 0.68300453]
#  [-1.28483001]]

# %%
# predict top 10 rate SA2:

# %%
y_pred_mlp = clf.predict(df_ceshi_scaled)

# %%
y_scaler.inverse_transform(y_pred_mlp.reshape((-1, 1)))
# Out:
# array([[ 0.13532672],
#        [ 0.24727679],
#        [ 0.3077363 ],
#        [ 0.18103812],
#        [ 0.30546762],
#        [ 0.14878789],
#        [ 0.2579098 ],
#        [ 0.17141809],
#        [ 0.13772881],
#        [ 0.14097116],
#        [ 0.34671403],
#        [ 0.30725589],
#        [ 0.2481585 ],
#        [ 0.35954366],
#        [ 0.27438942],
#        [ 0.29072158],
#        [ 0.34955583],
#        [ 0.23117392],
#        [ 0.26207953],
#        [ 0.14054622],
#        [ 0.1608923 ],
#        [ 0.19316137],
#        [ 0.20370149],
#        [ 0.20691622],
#        [ 0.15458383],
#        [ 0.13285746],
#        [ 0.11547359],
#        [ 0.22594463],
#        [ 0.26089871],
#        [ 0.29236798],
#        [ 0.27592591],
#        [ 0.31551637],
#        [ 0.23510385],
#        [ 0.35560442],
#        [ 0.26535829],
#        [ 0.06920209],
#        [ 0.19466636],
#        [ 0.25303503],
#        [ 0.13308572],
#        [ 0.14720418],
#        [ 0.12041518],
#        [ 0.12740968],
#        [ 0.15556947],
#        [ 0.16524328],
#        [ 0.15922549],
#        [ 0.11873267],
#        [ 0.17387708],
#        [ 0.04793073],
#        [ 0.17235856],
#        [ 0.15624999],
#        [ 0.15031987],
#        [ 0.20174166],
#        [ 0.32581402],
#        [ 0.33688982],
#        [ 0.32100087],
#        [ 0.13933966],
#        [ 0.07386755],
#        [ 0.20987144],
#        [ 0.27953545],
#        [ 0.27723004],
#        [ 0.14953209],
#        [ 0.35354742],
#        [ 0.26833308],
#        [ 0.28182352],
#        [ 0.18842761],
#        [ 0.25789208],
#        [ 0.29466426],
#        [ 0.29894926],
#        [ 0.27916674],
#        [ 0.21265976],
#        [ 0.36761074],
#        [ 0.26698172],
#        [ 0.31096289],
#        [ 0.27434114],
#        [ 0.27939886],
#        [ 0.31122982],
#        [ 0.14627425],
#        [ 0.25637105],
#        [ 0.05314406],
#        [ 0.16186608],
#        [ 0.19370848],
#        [ 0.29634964],
#        [ 0.24031819],
#        [ 0.20468833],
#        [ 0.18891062],
#        [ 0.31825666],
#        [ 0.28198145],
#        [ 0.24588784],
#        [ 0.30094767],
#        [ 0.30967541],
#        [ 0.2901919 ],
#        [ 0.27884624],
#        [ 0.29779863],
#        [ 0.29125426],
#        [ 0.13068533],
#        [ 0.19506457],
#        [ 0.16739235],
#        [ 0.21928601],
#        [ 0.13191569],
#        [ 0.15299045],
#        [ 0.27081294],
#        [ 0.16696731],
#        [ 0.19773302],
#        [ 0.1627201 ],
#        [ 0.28499251],
#        [ 0.0094015 ],
#        [ 0.09555484],
#        [ 0.12912171],
#        [ 0.0537285 ],
#        [ 0.02512828],
#        [ 0.12963577],
#        [ 0.13102768],
#        [ 0.09256082],
#        [ 0.10579931],
#        [ 0.07714325],
#        [ 0.05889901],
#        [ 0.08368354],
#        [ 0.06523385],
#        [ 0.09700572],
#        [ 0.15163448],
#        [ 0.10359106],
#        [ 0.00866405],
#        [-0.03957449],
#        [ 0.01910183],
#        [ 0.03917363],
#        [ 0.0266201 ],
#        [ 0.03908907],
#        [ 0.01132372],
#        [-0.0077055 ],
#        [-0.00845561],
#        [ 0.03729805],
#        [ 0.02611603],
#        [-0.00406421],
#        [ 0.02300323],
#        [ 0.0524989 ],
#        [ 0.04119128],
#        [ 0.07767544],
#        [ 0.02518421],
#        [ 0.00154868],
#        [ 0.05297384],
#        [ 0.02508833],
#        [ 0.04898475],
#        [ 0.06985243],
#        [-0.00293433],
#        [ 0.15577692],
#        [-0.07053175],
#        [ 0.0161244 ],
#        [-0.01803738],
#        [ 0.03166933],
#        [-0.02910032],
#        [ 0.01531569],
#        [ 0.03297015],
#        [ 0.04787312],
#        [-0.06639724],
#        [ 0.01503101],
#        [ 0.08240632],
#        [ 0.19404109],
#        [ 0.12760284],
#        [ 0.14547934],
#        [ 0.12523866],
#        [ 0.03331387],
#        [ 0.05609443],
#        [ 0.19146851],
#        [ 0.04414796],
#        [ 0.01667535],
#        [ 0.15153537],
#        [ 0.14284775],
#        [ 0.15878588],
#        [ 0.13523168],
#        [ 0.17915857],
#        [ 0.15802354],
#        [ 0.13176278],
#        [ 0.11009656],
#        [ 0.11350436],
#        [ 0.15628243],
#        [ 0.08999633],
#        [ 0.11715707],
#        [ 0.09557024],
#        [ 0.10648388],
#        [ 0.14723832],
#        [ 0.24815345],
#        [ 0.16030681],
#        [ 0.18774999],
#        [ 0.16453063],
#        [ 0.16030814],
#        [ 0.22305536],
#        [ 0.09600873],
#        [ 0.10972446],
#        [ 0.07258001],
#        [ 0.14876178],
#        [ 0.09941103],
#        [ 0.10883177],
#        [ 0.11694873],
#        [ 0.09515054],
#        [ 0.14974836],
#        [ 0.17963114],
#        [ 0.15098116],
#        [ 0.170577  ],
#        [ 0.16127841],
#        [ 0.14650878],
#        [ 0.10731094],
#        [ 0.1851142 ],
#        [ 0.19699938],
#        [ 0.15501083],
#        [ 0.13980455],
#        [ 0.08701354],
#        [ 0.09003399],
#        [ 0.10533558],
#        [ 0.13117382],
#        [ 0.16076159],
#        [ 0.14274684],
#        [ 0.16521202],
#        [ 0.12526429],
#        [ 0.1709744 ],
#        [ 0.12576427],
#        [ 0.14104215],
#        [ 0.12696056],
#        [ 0.1033366 ],
#        [ 0.1667423 ],
#        [ 0.14965902],
#        [ 0.10923677],
#        [ 0.14389491],
#        [ 0.15750085],
#        [ 0.11792374],
#        [ 0.13880269],
#        [ 0.20492033],
#        [ 0.22913483],
#        [ 0.16001787],
#        [ 0.08741833],
#        [ 0.17017248],
#        [ 0.11136168],
#        [ 0.13997745],
#        [ 0.12746192],
#        [ 0.09735661],
#        [ 0.20990386],
#        [ 0.08434496],
#        [ 0.08379141],
#        [ 0.09349638],
#        [ 0.09315337],
#        [ 0.08239042],
#        [ 0.08606013],
#        [ 0.10963585],
#        [ 0.08796094],
#        [ 0.08355544],
#        [ 0.0496146 ],
#        [ 0.07429847],
#        [ 0.07735964],
#        [ 0.08648332],
#        [ 0.05546335],
#        [ 0.15588796],
#        [ 0.16821942],
#        [ 0.13352364],
#        [ 0.16140235],
#        [ 0.15681005],
#        [ 0.15873079],
#        [ 0.16896409],
#        [ 0.12975042],
#        [ 0.15259373],
#        [ 0.13480314],
#        [ 0.150451  ],
#        [ 0.12486605],
#        [ 0.08635181],
#        [ 0.12010266],
#        [ 0.14617834],
#        [ 0.14263189],
#        [ 0.10541027],
#        [ 0.13268863],
#        [ 0.12735027],
#        [ 0.06070301],
#        [ 0.1228768 ],
#        [ 0.10799575],
#        [ 0.11929819],
#        [ 0.13843619],
#        [ 0.14028019],
#        [ 0.05644999],
#        [ 0.09928406],
#        [ 0.1220801 ],
#        [ 0.07868123],
#        [ 0.09023298],
#        [ 0.0812818 ],
#        [ 0.05311929],
#        [ 0.04772502],
#        [ 0.08367081],
#        [ 0.07453174],
#        [ 0.05433294],
#        [ 0.13960524],
#        [ 0.14144455],
#        [ 0.08897088],
#        [ 0.15388141],
#        [ 0.1515484 ],
#        [ 0.16064961],
#        [ 0.13808996],
#        [ 0.15371643],
#        [ 0.12522716],
#        [ 0.1460787 ],
#        [ 0.14027717],
#        [ 0.10223759],
#        [ 0.22739911],
#        [ 0.19367893],
#        [ 0.14716691],
#        [ 0.1570896 ],
#        [ 0.1426802 ],
#        [ 0.12681599],
#        [ 0.18938232],
#        [ 0.1638515 ],
#        [ 0.15864434],
#        [ 0.1184458 ],
#        [ 0.16087416],
#        [ 0.15531745],
#        [ 0.18176826],
#        [ 0.16476463],
#        [ 0.17797548],
#        [ 0.1548099 ],
#        [ 0.1355161 ],
#        [ 0.14884283],
#        [ 0.13278977],
#        [ 0.14665969],
#        [ 0.13987655],
#        [ 0.1347042 ],
#        [ 0.10414576],
#        [ 0.20848037],
#        [ 0.13092546],
#        [ 0.16937022],
#        [ 0.12278995],
#        [ 0.14459941],
#        [ 0.14487268],
#        [ 0.07295552],
#        [ 0.14084816],
#        [ 0.1094108 ],
#        [ 0.12428075],
#        [ 0.07280519],
#        [ 0.16661662],
#        [ 0.08515122],
#        [ 0.14158058],
#        [ 0.13276676],
#        [ 0.1099245 ],
#        [ 0.13914483],
#        [ 0.13328467],
#        [ 0.125313  ],
#        [ 0.12964913],
#        [ 0.13483295],
#        [ 0.10630169],
#        [ 0.11074044],
#        [ 0.13277765],
#        [ 0.0863782 ],
#        [ 0.09739298],
#        [ 0.08623406],
#        [ 0.13116337],
#        [ 0.1004629 ],
#        [ 0.109976  ],
#        [ 0.05851549],
#        [ 0.05609025],
#        [ 0.07911438],
#        [ 0.08083584],
#        [ 0.06820259],
#        [ 0.10771973],
#        [ 0.11285113],
#        [ 0.12097155],
#        [ 0.16227258],
#        [ 0.15660027],
#        [ 0.13627367],
#        [ 0.19244662],
#        [ 0.12966178],
#        [ 0.13056881],
#        [ 0.12448218],
#        [ 0.16639354],
#        [ 0.14794404],
#        [ 0.12466996],
#        [ 0.16508012],
#        [ 0.13328826],
#        [ 0.11356502],
#        [ 0.12834255],
#        [ 0.1328968 ],
#        [ 0.13152645],
#        [ 0.17166412],
#        [ 0.13843439],
#        [ 0.14406897],
#        [ 0.10973967],
#        [ 0.18345407],
#        [ 0.26012693],
#        [ 0.14909605],
#        [ 0.23796761],
#        [ 0.1038104 ],
#        [ 0.14455186],
#        [ 0.14680801],
#        [ 0.13753436],
#        [ 0.1655075 ],
#        [ 0.17620989],
#        [ 0.19174607],
#        [ 0.1346635 ],
#        [ 0.16862683],
#        [ 0.15595886],
#        [ 0.19798124],
#        [ 0.15862205],
#        [ 0.07670656],
#        [ 0.21511551],
#        [ 0.1751876 ],
#        [ 0.17631076],
#        [ 0.10162333],
#        [ 0.19185366],
#        [ 0.19817871],
#        [ 0.13220434],
#        [ 0.1446795 ],
#        [ 0.17058223],
#        [ 0.15702689],
#        [ 0.15879742],
#        [ 0.07762755],
#        [ 0.10891382],
#        [ 0.12300158],
#        [ 0.08198462],
#        [ 0.08936357],
#        [ 0.14165583],
#        [ 0.11728767],
#        [ 0.11363646],
#        [ 0.08729855],
#        [ 0.04919102],
#        [ 0.10148787],
#        [ 0.07612   ],
#        [ 0.14343594],
#        [ 0.10785063],
#        [ 0.11125241],
#        [ 0.13680687],
#        [ 0.15326052],
#        [ 0.16096725],
#        [ 0.14677961],
#        [ 0.16346997],
#        [ 0.06989145],
#        [ 0.07221445],
#        [ 0.16354955],
#        [ 0.09153314],
#        [ 0.07641137],
#        [ 0.16345012],
#        [ 0.10601616],
#        [ 0.03715518],
#        [ 0.03250984],
#        [ 0.0468208 ],
#        [ 0.10310134],
#        [ 0.03787451],
#        [ 0.08611353],
#        [ 0.09210162],
#        [ 0.07697009],
#        [ 0.12357549],
#        [ 0.14632141],
#        [ 0.15826308],
#        [ 0.18646885],
#        [ 0.18361893],
#        [ 0.11664033],
#        [ 0.18859702],
#        [ 0.17202915],
#        [ 0.18364495],
#        [ 0.3513272 ],
#        [ 0.1648368 ],
#        [ 0.20423403],
#        [ 0.18298529],
#        [ 0.21883073],
#        [ 0.21856981],
#        [ 0.17878233],
#        [ 0.1834799 ],
#        [ 0.27362814],
#        [ 0.19454269],
#        [ 0.38649291],
#        [ 0.20300896],
#        [ 0.35662715],
#        [ 0.23241072],
#        [ 0.30395468],
#        [ 0.21050325],
#        [ 0.400853  ],
#        [ 0.2236743 ],
#        [ 0.19502772],
#        [ 0.31154342],
#        [ 0.40084706],
#        [ 0.28000264],
#        [ 0.19634309],
#        [ 0.19890292],
#        [ 0.22768221],
#        [ 0.25754732],
#        [ 0.29432419],
#        [ 0.4607192 ],
#        [ 0.16250451],
#        [ 0.25424299],
#        [ 0.20889018],
#        [ 0.18709982],
#        [ 0.36399648],
#        [ 0.35162212],
#        [ 0.26989028],
#        [ 0.24638849],
#        [ 0.46860789],
#        [ 0.18167641],
#        [ 0.25020044],
#        [ 0.22161352],
#        [ 0.18342299],
#        [ 0.34061904],
#        [ 0.2132346 ],
#        [ 0.16569824],
#        [ 0.18037643],
#        [ 0.26738963],
#        [ 0.20774802],
#        [ 0.21148005],
#        [ 0.3363424 ],
#        [ 0.38574222],
#        [ 0.1929997 ],
#        [ 0.37231549],
#        [ 0.32877279],
#        [ 0.32066797],
#        [ 0.32728401],
#        [ 0.33024665],
#        [ 0.25754549],
#        [ 0.19488959],
#        [ 0.23333747]])

# %%
y_pred_lr = lr.predict(df_ceshi_scaled)

# %%
df_pred = pd.DataFrame()
df_pred['SA2_CODE21'] = df_ceshi['SA2_CODE16']
df_pred['ror_mlp_pred'] = y_scaler.inverse_transform(y_pred_mlp.reshape((-1, 1)))
df_pred['ror_lr_pred'] = y_scaler.inverse_transform(y_pred_lr.reshape((-1, 1)))

# %%
df_pred.sort_values(["ror_mlp_pred"] , ascending=False) [:10]
# Out:
#      SA2_CODE21  ror_mlp_pred  ror_lr_pred
# 499   216021412      0.468608     0.291951
# 490   215031403      0.460719     0.197406
# 479   215011393      0.400853     0.320143
# 483   215021398      0.400847     0.275606
# 473   215011387      0.386493     0.295874
# 512   217031471      0.385742     0.311038
# 514   217031473      0.372315     0.256899
# 71    204021067      0.367611     0.247050
# 495   216011408      0.363996     0.264576
# 13    201021012      0.359544     0.215883

# %%
df_pred.sort_values(["ror_lr_pred"] , ascending=False)[:10]
# Out:
#      SA2_CODE21  ror_mlp_pred  ror_lr_pred
# 91    205021086      0.300948     0.367584
# 54    203031052      0.321001     0.341322
# 53    203031051      0.336890     0.339677
# 90    205021085      0.245888     0.330823
# 477   215011391      0.303955     0.327841
# 14    201031013      0.274389     0.325913
# 489   215031402      0.294324     0.325321
# 497   216011410      0.269890     0.324798
# 110   205051104      0.284993     0.320194
# 479   215011393      0.400853     0.320143

# %%
print("Top 10 growth rate SA2_CODE(MLP predict) are ",df_pred.sort_values(["ror_mlp_pred"] , ascending=False)[:10].SA2_CODE21.values)
# Out:
# Top 10 growth rate SA2_CODE(MLP predict) are  [216021412 215031403 215011393 215021398 215011387 217031471 217031473
#  204021067 216011408 201021012]

# %%
print("Top 10 growth rate SA2_CODE(LR predict) are ",df_pred.sort_values(["ror_lr_pred"] , ascending=False)[:10].SA2_CODE21.values)
# Out:
# Top 10 growth rate SA2_CODE(LR predict) are  [205021086 203031052 203031051 205021085 215011391 201031013 215031402
#  216011410 205051104 215011393]
