# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel(r'C:\Users\lenovo\Desktop\moving.xlsx')

# %%
df
# Out:
#      Inner Melbourne  Inner Eastern Melbourne  Southern Melbourne  \
# 0              25935                    16751               12441
# 1                240                      200                 195
# 2              26236                    16669               12478
# 3                240                      210                 200
# 4              26763                    16821               12613
# ..               ...                      ...                 ...
# 169              400                      450                 460
# 170            67010                    25841               17268
# 171              400                      440                 450
# 172            67158                    26442               17659
# 173              390                      440                 450
#
#      Outer Western Melbourne  North Western Melbourne  \
# 0                      10897                    10296
# 1                        160                      170
# 2                      11038                    10422
# 3                        160                      170
# 4                      11314                    10572
# ..                       ...                      ...
# 169                      380                      400
# 170                    29201                    19793
# 171                      380                      400
# 172                    29940                    20274
# 173                      380                      395
#
#      North Eastern Melbourne  Outer Eastern Melbourne  \
# 0                      10600                     6907
# 1                        170                      170
# 2                      10581                     6860
# 3                        175                      170
# 4                      10873                     7035
# ..                       ...                      ...
# 169                      400                      420
# 170                    17199                     7279
# 171                      400                      420
# 172                    17728                     7550
# 173                      400                      420
#
#      South Eastern Melbourne  Mornington Peninsula  Geelong  Ballarat  \
# 0                       8533                  6451     4938      3338
# 1                        150                   150      135       135
# 2                       8512                  6541     4902      3300
# 3                        155                   150      140       135
# 4                       8544                  6683     4959      3362
# ..                       ...                   ...      ...       ...
# 169                      380                   400      370       330
# 170                    15198                  6829     6276      4317
# 171                      380                   415      380       340
# 172                    15532                  6677     6091      4118
# 173                      385                   420      385       350
#
#      Bendigo  Other Regional Centres
# 0       2728                   13871
# 1        135                     130
# 2       2688                   13787
# 3        140                     130
# 4       2772                   13842
# ..       ...                     ...
# 169      330                     330
# 170     2639                   12253
# 171      340                     340
# 172     2553                   11833
# 173      350                     350
#
# [174 rows x 13 columns]

# %%
df_count = df[df.index%2==0]
df_median = df[df.index%2==1]

# %%
df_count
# Out:
#      Inner Melbourne  Inner Eastern Melbourne  Southern Melbourne  \
# 0              25935                    16751               12441
# 2              26236                    16669               12478
# 4              26763                    16821               12613
# 6              26844                    16765               12632
# 8              27104                    16701               12780
# ..               ...                      ...                 ...
# 164            51643                    23408               15978
# 166            56731                    23723               16042
# 168            61458                    23869               16202
# 170            67010                    25841               17268
# 172            67158                    26442               17659
#
#      Outer Western Melbourne  North Western Melbourne  \
# 0                      10897                    10296
# 2                      11038                    10422
# 4                      11314                    10572
# 6                      11434                    10518
# 8                      11454                    10503
# ..                       ...                      ...
# 164                    27530                    18363
# 166                    27707                    18561
# 168                    28139                    18903
# 170                    29201                    19793
# 172                    29940                    20274
#
#      North Eastern Melbourne  Outer Eastern Melbourne  \
# 0                      10600                     6907
# 2                      10581                     6860
# 4                      10873                     7035
# 6                      10746                     7027
# 8                      10652                     7039
# ..                       ...                      ...
# 164                    16633                     7966
# 166                    16632                     7585
# 168                    16581                     7369
# 170                    17199                     7279
# 172                    17728                     7550
#
#      South Eastern Melbourne  Mornington Peninsula  Geelong  Ballarat  \
# 0                       8533                  6451     4938      3338
# 2                       8512                  6541     4902      3300
# 4                       8544                  6683     4959      3362
# 6                       8427                  6612     4921      3345
# 8                       8433                  6560     4879      3127
# ..                       ...                   ...      ...       ...
# 164                    16296                  7961     6416      4503
# 166                    15686                  7488     6462      4459
# 168                    15128                  7090     6310      4348
# 170                    15198                  6829     6276      4317
# 172                    15532                  6677     6091      4118
#
#      Bendigo  Other Regional Centres
# 0       2728                   13871
# 2       2688                   13787
# 4       2772                   13842
# 6       2724                   13603
# 8       2638                   13232
# ..       ...                     ...
# 164     2907                   13508
# 166     2805                   12913
# 168     2688                   12452
# 170     2639                   12253
# 172     2553                   11833
#
# [87 rows x 13 columns]

# %%
ans = []
for i in range(2000,2022):
    for j in ['03','06','09','12']:
        ans.append(str(i)+'-'+j)

# %%
ans = ans[:-1]

# %%
len(ans)
# Out:
# 87

# %%
color = ['b', 'c', 'g', 'k',
'm', 'r', 'orange', 'y',
'fuchsia',
'gainsboro',
'ghostwhite',
'gold',
'goldenrod']

# %%
sns.set()
plt.figure(figsize=(15,5))
for index,i in enumerate(df_count.columns):
    plt.plot(ans,df_count[i],color = color[index], label=i)

plt.xlabel('time')
plt.ylabel('count')
plt.xticks(np.arange(0,87))
plt.xticks(rotation=280)
plt.title('Moving annual rent by suburb')
plt.legend()
plt.show()

# %%
sns.set()
plt.figure(figsize=(15,5))
for index,i in enumerate(df_median.columns):
    plt.plot(ans,df_median[i],color = color[index], label=i)

plt.xlabel('time')
plt.ylabel('median')
plt.xticks(np.arange(0,87))
plt.xticks(rotation=280)
plt.title('Moving annual rent by suburb')
plt.legend()
plt.show()
