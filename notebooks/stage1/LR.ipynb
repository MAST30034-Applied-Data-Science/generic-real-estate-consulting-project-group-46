# %% [markdown]
# # Linear Regression
# This noteboooks is for linear regression model for stage one (find most important feature).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.formula.api import ols, glm
from statsmodels.api import families
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
df = pd.read_csv("../data/curated/df_domain_final2.csv")
df['school_distance'] = df['school_distance'].str.replace("", "")
df['suburb_population'] = df['suburb_population'].str.replace(",", "")
df['suburb_sold'] = df['suburb_sold'].str.replace("-", "0")
df['suburb_avg_day'] = df['suburb_avg_day'].str.replace("-", "0")
df[['suburb_population','suburb_avg_day','suburb_sold']]\
= df[['suburb_population','suburb_avg_day','suburb_sold']].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'suburb_population'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/xx/831dtzvs55b0c08vg3m5yhf40000gn/T/ipykernel_4308/412710822.py in <module>
#       1 df = pd.read_csv("../data/curated/df_domain_final2.csv")
# ----> 2 df['suburb_population'] = df['suburb_population'].str.replace(",", "")
#       3 df['suburb_sold'] = df['suburb_sold'].str.replace("-", "0")
#       4 df['suburb_avg_day'] = df['suburb_avg_day'].str.replace("-", "0")
#       5 df[['suburb_population','suburb_avg_day','suburb_sold']]\
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'suburb_population'

# %%
df
# Out:
#                                                      url  \
# 0      https://www.domain.com.au/1202-620-collins-str...
# 1      https://www.domain.com.au/1701-620-collins-str...
# 2      https://www.domain.com.au/5707b-639-little-lon...
# 3      https://www.domain.com.au/1003-225-elizabeth-s...
# 4      https://www.domain.com.au/1202-31-spring-stree...
# ...                                                  ...
# 12762  https://www.domain.com.au/6-bruce-street-inver...
# 12763  https://www.domain.com.au/14-inverloch-parade-...
# 12764  https://www.domain.com.au/inverloch-vic-3996-1...
# 12765  https://www.domain.com.au/25a-veronica-street-...
# 12766  https://www.domain.com.au/28-beachcomber-drive...
#
#                       coordinates   longitude   latitude  \
# 0      [-37.8186626, 144.9543471]  144.954347 -37.818663
# 1      [-37.8186626, 144.9543471]  144.954347 -37.818663
# 2      [-37.8141942, 144.9521662]  144.952166 -37.814194
# 3      [-37.8132308, 144.9623173]  144.962317 -37.813231
# 4      [-37.8145047, 144.9740695]  144.974070 -37.814505
# ...                           ...         ...        ...
# 12762  [-38.6303499, 145.7311203]  145.731120 -38.630350
# 12763  [-38.6287143, 145.7358082]  145.735808 -38.628714
# 12764  [-38.6314613, 145.7293638]  145.729364 -38.631461
# 12765  [-38.6428993, 145.7101579]  145.710158 -38.642899
# 12766  [-38.6412502, 145.7031282]  145.703128 -38.641250
#
#                               geometry  dist_nearest_busstop  \
# 0      POINT (144.9543471 -37.8186626)               1000000
# 1      POINT (144.9543471 -37.8186626)               1000000
# 2      POINT (144.9521662 -37.8141942)               1000000
# 3      POINT (144.9623173 -37.8132308)               1000000
# 4      POINT (144.9740695 -37.8145047)               1000000
# ...                                ...                   ...
# 12762  POINT (145.7311203 -38.6303499)               1000000
# 12763  POINT (145.7358082 -38.6287143)               1000000
# 12764  POINT (145.7293638 -38.6314613)               1000000
# 12765  POINT (145.7101579 -38.6428993)               1000000
# 12766  POINT (145.7031282 -38.6412502)               1000000
#
#        dist_nearest_trainstation  dist_nearest_primary_school  \
# 0                        1000000                      1000000
# 1                        1000000                      1000000
# 2                        1000000                      1000000
# 3                        1000000                      1000000
# 4                        1000000                      1000000
# ...                          ...                          ...
# 12762                    1000000                      1000000
# 12763                    1000000                      1000000
# 12764                    1000000                      1000000
# 12765                    1000000                      1000000
# 12766                    1000000                      1000000
#
#        dist_nearest_secondary_school
# 0                            1000000
# 1                            1000000
# 2                            1000000
# 3                            1000000
# 4                            1000000
# ...                              ...
# 12762                        1000000
# 12763                        1000000
# 12764                        1000000
# 12765                        1000000
# 12766                        1000000
#
# [12767 rows x 9 columns]

# %%
# aggregate data by psotcode
df_postcode = df\
                .groupby('postcode') \
                .agg(
                    {
                        'cost':'mean',
                        'Median_rent_weekly':'mean',
                        'school_distance':'mean',
                        'dist_nearest_busstop':'mean',
                        'dist_nearest_trainstation':'mean',
                        'dist_nearest_primary_school':'mean',
                        'dist_nearest_secondary_school':'mean',
                        'Beds':'mean',
                        'Bath':'mean',
                        'Parking':'mean',
                        'avg_income':'mean',
                        'Tot_P_P':'mean',
                        'Median_age_persons': 'mean',
                        'suburb_sold': 'mean',
                        'suburb_avg_day': 'mean',
                        'suburb_population': 'mean',
                        'suburb_owner': 'mean',
                        'suburb_renter':'mean',
                        'suburb_family':'mean',
                        'suburb_single':'mean',
                    }
                ) 
df_postcode.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/xx/831dtzvs55b0c08vg3m5yhf40000gn/T/ipykernel_4308/1892284414.py in <module>
#       1 # aggregate data by psotcode
# ----> 2 df_postcode = df\
#       3                 .groupby('postcode') \
#       4                 .agg(
#       5                     {
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     977
#     978         op = GroupByApply(self, func, args, kwargs)
# --> 979         result = op.agg()
#     980         if not is_dict_like(func) and result is not None:
#     981             return result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in agg(self)
#     159
#     160         if is_dict_like(arg):
# --> 161             return self.agg_dict_like()
#     162         elif is_list_like(arg):
#     163             # we require a list, but not a 'str'
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in agg_dict_like(self)
#     425             selection = obj._selection
#     426
# --> 427         arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     428
#     429         if selected_obj.ndim == 1:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in normalize_dictlike_arg(self, how, obj, func)
#     544             if len(cols) > 0:
#     545                 cols_sorted = list(safe_sort(list(cols)))
# --> 546                 raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     547
#     548         is_aggregator = lambda x: isinstance(x, (list, tuple, dict))
#
# KeyError: "Column(s) ['Median_age_persons', 'Median_rent_weekly', 'Tot_P_P', 'avg_income', 'dist_nearest_busstop', 'dist_nearest_primary_school', 'dist_nearest_secondary_school', 'dist_nearest_trainstation'] do not exist"

# %%
# check linear relationship between features and respond varible
sns.lmplot(x="suburb_population", y="cost", data=df_postcode)

# %%
sns.lmplot(x="dist_nearest_busstop", y="cost", data=df_postcode)

# %%
sns.lmplot(x="avg_income", y="cost", data=df_postcode)

# %%
# check correlation of features

CORR_COLS = [
    'cost','school_distance','suburb_population','suburb_renter',
    'suburb_single','dist_nearest_secondary_school', 'dist_nearest_busstop',
    'dist_nearest_trainstation' , 'dist_nearest_primary_school',
    'avg_income','Tot_P_P','Median_age_persons','Beds','Bath','Parking'
]


fig,ax = plt.subplots(figsize=(17,5)) 
sns.heatmap(df_postcode[CORR_COLS].corr(), cmap = plt.cm.RdYlBu_r,annot=True, ax = ax)

plt.title('Pearson Correlation Metric')
#plt.savefig('../plots/corr.png')

# %%
CORR_COLS = [
    'cost','school_distance','suburb_population','suburb_renter',
    'dist_nearest_secondary_school','dist_nearest_trainstation' , 
    'avg_income','Tot_P_P','Median_age_persons','Beds','Bath','Parking'
]


fig,ax = plt.subplots(figsize=(20,5)) 
sns.heatmap(df_postcode[CORR_COLS].corr(), cmap = plt.cm.RdYlBu_r,annot=True, ax = ax)

plt.title('Pearson Correlation Metric')
#plt.savefig('../plots/corr.png')

# %%
x = df_postcode[['cost','suburb_population','suburb_renter','suburb_family',
    'dist_nearest_secondary_school','dist_nearest_trainstation' , 
    'avg_income','Tot_P_P','Median_age_persons','Beds','Bath','Parking']].values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df1 = pd.DataFrame(x_scaled, columns= ['cost','suburb_population','suburb_renter','suburb_family',
    'dist_nearest_secondary_school','dist_nearest_trainstation' , 
    'avg_income','Tot_P_P','Median_age_persons','Beds','Bath','Parking'] )

# %%
df1

# %%
# training model
fit = ols(
    formula="cost ~ suburb_population + suburb_renter + suburb_family + dist_nearest_secondary_school + avg_income \
    + Tot_P_P + dist_nearest_trainstation + Median_age_persons + Bath + Parking",
    data=df1
).fit()
print(fit.summary())

# %%
fit = ols(
    formula="cost ~ avg_income + Tot_P_P + dist_nearest_trainstation + Median_age_persons + Bath + Parking",
    data=df1
).fit()
print(fit.summary())
